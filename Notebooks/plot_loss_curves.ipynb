# %%
import sys
import os

sys.path.append(r'C:\Users\shrey\Desktop\RL rubicks cube')

# %%
import torch
from Models import ResnetModel
from utils import load_model, plot_losses

# %%
# Load model and losses
model_path = r"..\trained_models\3x3\best_model_epoch_97.pt"
nnet = ResnetModel(state_dim=54, one_hot_depth=6, h1_dim=5000, resnet_dim=1000, num_resnet_blocks=4,
                   policy_out_dim=12, value_out_dim=1, batch_norm=True, dropout=0.1)

epoch, val_loss, train_policy_losses, train_value_losses, val_policy_losses, val_value_losses = load_model(
    model_path, nnet)

# Plot losses
plot_losses(train_policy_losses, train_value_losses, val_policy_losses, val_value_losses, model_dir=".")
# Out:
# Model and optimizer loaded from ..\trained_models\3x3\best_model_epoch_97.pt (Epoch 97)
